# %% [markdown]
# # 01 — Narrative pipeline demo
#
# - Date: TBD
# - Author: Polina Bakhturina
# - Hypothesis: Layer 1 produces interpretable `NarrativeFeatures` for a sample text.
# - Inputs: `configs/prototype.yaml`, one text from `data/raw/stories/`.
# - Outputs: a single `NarrativeFeatures` JSON saved under `data/processed/narrative_features/`.
#
# Placeholder — populate during W1–W4 of the prototype.

# %%
# %load_ext autoreload
# %autoreload 2

from story2belief import __version__
print('story2belief', __version__)

# %% [markdown]
# ## Takeaways
# - _to fill in_
#
# ## Next steps
# - [ ] _to fill in_
