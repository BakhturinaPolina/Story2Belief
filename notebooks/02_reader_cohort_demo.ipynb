# %% [markdown]
# # 02 — Reader cohort demo
#
# - Date: TBD
# - Author: Polina Bakhturina
# - Hypothesis: Sampled cohort traits cover the planned ranges and produce contrastable agent personas.
# - Inputs: `configs/reader_profiles.yaml`.
# - Outputs: a small cohort table and a trait-distribution plot.
#
# Placeholder — populate during W5–W8.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Takeaways
# - _to fill in_
#
# ## Next steps
# - [ ] _to fill in_
