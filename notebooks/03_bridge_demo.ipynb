# %% [markdown]
# # 03 — Bridge (moral transfer) demo
#
# - Date: TBD
# - Author: Polina Bakhturina
# - Hypothesis: Pre/post deltas can be computed for one (reader, text, dilemma) triple end-to-end.
# - Inputs: cohort + reading responses from notebook 02; one dilemma from `data/external/`.
# - Outputs: a single `TransferDeltas` record + a small plot.
#
# Placeholder — populate during W9–W12.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Takeaways
# - _to fill in_
#
# ## Next steps
# - [ ] _to fill in_
