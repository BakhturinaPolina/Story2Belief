# %% [markdown]
# # 04 — End-to-end prototype demo
#
# - Date: TBD
# - Author: Polina Bakhturina
# - Hypothesis: Two contrasting texts × a synthetic cohort × pre/post dilemmas produce interpretable transfer deltas.
# - Inputs: `configs/prototype.yaml`, all artifacts in `data/processed/`.
# - Outputs: the five committee-facing deliverables (schema diagram, feature table, cohort table, transfer-delta plot, methods memo).
#
# Placeholder — committee demo at end of W12.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Takeaways
# - _to fill in_
#
# ## Next steps
# - [ ] _to fill in_
